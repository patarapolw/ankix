# %%
from ankix import Ankix
db = Ankix('test.ankix')

# %%
db_card = db['card'].select()[20]

# %%
db_card
# Out:
# <Card: 1461857288181>

# %%
iter_quiz = db.iter_quiz()

# %%
card = next(iter_quiz)
card
# Out:
# <Card: 1476496210935>

# %%
card.wrong()

# %%
card.right()

# %%
db.tables
# Out:
# {'tag': <Model: Tag>,
#  'media': <Model: Media>,
#  'model': <Model: Model>,
#  'template': <Model: Template>,
#  'deck': <Model: Deck>,
#  'note': <Model: Note>,
#  'card': <Model: Card>}
