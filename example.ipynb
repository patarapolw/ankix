# %%
from ankix import Ankix
db = Ankix('test.ankix')

# %%
db_card = db['card'].select()[0]

# %%
db_card.front
# Out:
# <div class="hanzi">我没有问题。</div>

# %%
db_card.back
# Out:
# <div class="hanzi">我没有问题。</div>
# <div class="spacer"> </div>
# <div class="english">
# 	<div class="pinyin">Wǒ méiyǒu wèntí.</div>
# 	<div class="spacerSmall"> </div>
# 	I don't have any questions.
# 	<div class="spacerMedium"> </div>
# 	<div class="notes"></div>
# </div>
#
#
# <div class="lessonInfo">
# <div class="spacer"> </div>
# <div>Pattern: <span class="lessonInfoHanzi">没 + 有 (+ Obj.)</span></div>
# Article: <a href=https://resources.allsetlearning.com/chinese/grammar/ASGPNV3Q>Negation of "you" with "mei"</a>
# </div>

# %%
iter_quiz = db.iter_quiz()

# %%
card = next(iter_quiz)
card
# Out:
# <Card: 1520716975640>

# %%
card.show()
# Out:
# <div class="hanzi">雨这么大，明天再去吧。</div>
# <div class="spacer"> </div>
# <div class="english">
#     <div class="pinyin">Yǔ zhème dà, míngtiān zài qù ba.</div>
#     <div class="spacerSmall"> </div>
#     It's raining so heavily. How about we go tomorrow?
#     <div class="spacerMedium"> </div>
#     <div class="notes"></div>
# </div><div class="lessonInfo">
# <div class="spacer"> </div>
# <div>Pattern: <span class="lessonInfoHanzi">Subj. + 那么 / 这么 + Adj.</span></div>
# Article: <a href=https://resources.allsetlearning.com/chinese/grammar/ASGNKKP6>Adjectives with "name" and "zheme"</a>
# </div>

# %%
card.wrong()
